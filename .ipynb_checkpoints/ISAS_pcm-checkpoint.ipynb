# %% [markdown]
# # Apply PCM to ISAS dataset

# %% [markdown]
# Apply PCM method to ISAS dataset (example for a gridded product)

# %%
import xarray as xr
import numpy as np

import pyxpcm
from pyxpcm.models import pcm

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import seaborn as sns

from Plotter import Plotter #new class for plots in pyxpcm

# %% [markdown]
# ## Get data
# ***

# %%
ds_path = '/home5/pharos/REFERENCE_DATA/OCEAN_REP/ISAS/ISAS15/ANA/ISAS_DT/ARGO_ONLY/2015/ISAS15_ARGO_20151215_fld_TEMP.nc'

# %% [markdown]
# <font color=red>__TODO__</font> : use more than one time step (more tha one file)

# %%
ds_raw = xr.open_dataset(ds_path)
#ds_raw

# %%
ds_raw['depth'] = -ds_raw.depth
#ds_raw

# %% [markdown]
# <font color=blue>__select data in mediterranean__</font>

# %%
ds = ds_raw.sel(latitude=slice(30,45), longitude=slice(-6, 35))
# ds

# %%
ds['TEMP'].isel(time=0, depth=0).plot();

# %% [markdown]
# ## Applying PCM
# ***

# %% [markdown]
# ### Create PCM

# %%
z = np.arange(0.,-2000,-10.)
pcm_features = {'temperature': z}
m = pcm(K=8, features=pcm_features)
m
# Out:
# <pcm 'gmm' (K: 8, F: 1)>
# Number of class: 8
# Number of feature: 1
# Feature names: odict_keys(['temperature'])
# Fitted: False
# Feature: 'temperature'
# 	 Interpoler: <class 'pyxpcm.utils.Vertical_Interpolator'>
# 	 Scaler: 'normal', <class 'sklearn.preprocessing._data.StandardScaler'>
# 	 Reducer: True, <class 'sklearn.decomposition._pca.PCA'>
# Classifier: 'gmm', <class 'sklearn.mixture._gaussian_mixture.GaussianMixture'>

# %% [markdown]
# ### Fit Model

# %%
features_in_ds = {'temperature': 'TEMP'}
features_zdim='depth'
m.fit(ds, features=features_in_ds, dim=features_zdim)
m
# Out:
# <pcm 'gmm' (K: 8, F: 1)>
# Number of class: 8
# Number of feature: 1
# Feature names: odict_keys(['temperature'])
# Fitted: True
# Feature: 'temperature'
# 	 Interpoler: <class 'pyxpcm.utils.Vertical_Interpolator'>
# 	 Scaler: 'normal', <class 'sklearn.preprocessing._data.StandardScaler'>
# 	 Reducer: True, <class 'sklearn.decomposition._pca.PCA'>
# Classifier: 'gmm', <class 'sklearn.mixture._gaussian_mixture.GaussianMixture'>
# 	 log likelihood of the training set: 22.362833

# %% [markdown]
# <font color=red>__TODO__</font> : save all trained PCM in a folder

# %% [markdown]
# ### Classify data

# %%
m.predict(ds, features=features_in_ds, dim=features_zdim, inplace=True);
#ds

# %%
m.predict_proba(ds, features=features_in_ds, dim=features_zdim, inplace=True);
#ds

# %%
ds = ds.pyxpcm.quantile(m, q=[0.05, 0.5, 0.95], of='TEMP', outname='TEMP' + '_Q', keep_attrs=True, inplace=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (depth: 152, latitude: 38, longitude: 83, pcm_class: 8, quantile: 3, time: 1)
# Coordinates:
#   * pcm_class    (pcm_class) int64 0 1 2 3 4 5 6 7
#   * longitude    (longitude) float64 -6.0 -5.5 -5.0 -4.5 ... 33.5 34.0 34.5 35.0
#   * latitude     (latitude) float64 30.02 30.46 30.89 ... 43.93 44.29 44.65
#   * depth        (depth) float32 -1.0 -3.0 -5.0 ... -1960.0 -1980.0 -2000.0
#   * time         (time) datetime64[ns] 2015-12-15
#   * quantile     (quantile) float64 0.05 0.5 0.95
# Data variables:
#     TEMP         (time, depth, latitude, longitude) float32 nan nan ... nan nan
#     TEMP_ERR     (time, depth, latitude, longitude) float32 nan nan ... nan nan
#     TEMP_PCTVAR  (time, depth, latitude, longitude) float32 100.0 ... 100.0
#     PCM_LABELS   (time, latitude, longitude) float64 nan nan nan ... nan nan nan
#     PCM_POST     (pcm_class, time, latitude, longitude) float64 nan nan ... nan
#     TEMP_Q       (pcm_class, quantile, depth) float64 19.21 19.32 ... 13.84
# Attributes:
#     Conventions:            CF-1.4
#     title:                  Monthly analysis
#     history:                20171123T115459L : Creation
#     institution:            LOPS-SNO-Argo
#     project_name:           ISAS-LOPS
#     analysis_name:          ISAS15_ARGO_
#     data_manager:           Nicolas-Kolodziejczyk
#     software_version:       POSTOA_main - 7.0
#     southernmost_latitude:  -77.0105
#     northernmost_latitude:  89.8963
#     latitude_resolution:    0.49999365
#     westernmost_longitude:  -180
#     easternmost_longitude:  179.5
#     longitude_resolution:   0.5
#     start_date:             2015-12-15
#     stop_date:              2015-12-15
#     creation_date:          20171123T115459L
#     reference_date:         1950-01-01T00:00:00Z
#     references:             Gaillard et al., JCLIM 2016, Doi:10.1175/JCLI-D-1...
#     comment:                V7.0 T and S fields

# %% [markdown]
# ## Visualisation
# ***

# %%
P = Plotter(ds.squeeze(), m, data_type = 'gridded')

# %% [markdown]
# #### 1. Vertical structure of classes

# %%
#fig, ax = m.plot.quantile(ds['TEMP_Q'], maxcols=4, figsize=(10, 8), sharey=True)
P.vertical_structure(q_variable = 'TEMP_Q')

# %% [markdown]
# #### 2. Spatial distribution of classes

# %%
P.spatial_distribution(proj=ccrs.PlateCarree(), 
                       extent=np.array([-10,40,30,56]) + np.array([-0.1,+0.1,-0.1,+0.1]), 
                       co = {'latitude':'latitude', 'longitude':'longitude'})

# %% [markdown]
# #### 3. Posteriors

# %%
P.plot_posteriors(proj=ccrs.PlateCarree(), extent=np.array([-10,40,30,56]) + np.array([-0.1,+0.1,-0.1,+0.1]), 
                       co = {'latitude':'latitude', 'longitude':'longitude'})

# %% [markdown]
# #### 4. Temporal representation

# %% [markdown]
# Temporal representation has no sense because only one time step
